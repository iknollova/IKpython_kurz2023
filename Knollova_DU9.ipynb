# %%
import pandas

zam_praha = pandas.read_csv("https://github.com/JankaMarschalkova/python-podzim-pondeli-2023/blob/main/ukoly/zam_praha.csv")
zam_plzen = pandas.read_csv("https://github.com/JankaMarschalkova/python-podzim-pondeli-2023/blob/main/ukoly/zam_plzen.csv")
zam_liberec = pandas.read_csv("https://github.com/JankaMarschalkova/python-podzim-pondeli-2023/blob/main/ukoly/zam_liberec.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\ilona\Documents\ilona\Czechitas\Python_semkurz\9lekce\excs\DU9.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ilona/Documents/ilona/Czechitas/Python_semkurz/9lekce/excs/DU9.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ilona/Documents/ilona/Czechitas/Python_semkurz/9lekce/excs/DU9.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> zam_praha = pandas.read_csv("https://github.com/JankaMarschalkova/python-podzim-pondeli-2023/blob/main/ukoly/zam_praha.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/ilona/Documents/ilona/Czechitas/Python_semkurz/9lekce/excs/DU9.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> zam_plzen = pandas.read_csv("https://github.com/JankaMarschalkova/python-podzim-pondeli-2023/blob/main/ukoly/zam_plzen.csv")
# ...

# %% [markdown]
# načteni z harddisku, z URL mně nefunguje.

# %%
import pandas
zam_praha = pandas.read_csv("zam_praha.csv")
zam_liberec = pandas.read_csv("zam_liberec.csv")
zam_plzen = pandas.read_csv("zam_plzen.csv")

# %%
zam_praha
# Out:
#           jmeno  prijimeni   telefonni_cislo  cislo_zamestnance
# 0         Brian       Hall  +421 949 656 098                 30
# 1         Marta   Kolářová       730 456 163                 32
# 2          John    Moravec       725 092 179                 33
# 3      Dominika    Kopecká       722 747 626                 34
# 4        Marcel      Hájek  +421 902 928 669                 35
# 5        Milada  Hernandez       773 373 704                 38
# 6     Catherine     Bender       604 068 460                 40
# 7          Olga    Němcová  +421 914 172 243                 41
# 8       Jeffrey    Šťastný       607 628 821                 44
# 9        Kamila     Říhová  +421 948 396 069                 47
# 10      Jaromír     Miller  +421 912 615 902                 49
# 11  Christopher      Zeman  +421 948 150 084                 51
# 12     Karolína      Short       721 589 083                 53
# 13     Michelle    Vlčková  +421 41 720 7806                 54
# ...

# %%
zam_plzen
# Out:
#         jmeno    prijimeni   telefonni_cislo  cislo_zamestnance
# 0       Stacy  Pospíšilová       727 293 880                  3
# 1       Matěj         Král       770 787 377                  6
# 2      Amanda       Wilson  +421 52 656 7231                  7
# 3       Angel       Wilson  +421 52 135 2491                  8
# 4    Jindřich       Howell  +421 39 043 0948                 10
# 5   Alexander     Martinez       721 195 689                 13
# 6       Radim      Kopecký  +421 917 371 226                 16
# 7    Miroslav         Reed       774 829 074                 18
# 8      Emilie       Powell       731 380 539                 21
# 9      Nikola         Wade       726 763 154                 22
# 10  Katherine         Reed       726 214 968                 23
# 11      Kayla     Urbanová       737 772 985                 24
# 12      Roman       Moreno       722 284 985                 26
# 13   Bohumila        Smith       608 121 912                 27
# ...

# %%
zam_liberec
# Out:
#         jmeno    prijimeni   telefonni_cislo  cislo_zamestnance
# 0        Nela      Šťastná       728 454 176                 83
# 1     Heather      Marková       604 404 522                 84
# 2      Krista  Procházková  +421 50 444 5544                 85
# 3    Jennifer        Brown       775 545 190                 86
# 4   Ladislava    Blackwell  +421 913 487 200                 87
# 5      Robert       Macias  +421 49 929 6856                 88
# 6        Dana        Reyes  +421 904 153 942                 90
# 7       Vasyl       Veselý       603 759 413                 92
# 8       Randy       Veselý       777 149 125                 95
# 9      Audrey        Allen  +421 908 839 506                 96
# 10       Ivan       Bartoš       603 226 051                 99

# %% [markdown]
# Přidání sloupečku pracoviště

# %%
zam_praha["pracoviste"]="Praha"
zam_plzen["pracoviste"]="Plzen"
zam_liberec["pracoviste"]="Liberec"

# %% [markdown]
# Spojení všech  tabulek

# %%
zamestnanci= pandas.concat([zam_praha,zam_plzen, zam_liberec],ignore_index=True)
zamestnanci
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance pracoviste
# 0         Brian         Hall  +421 949 656 098                 30      Praha
# 1         Marta     Kolářová       730 456 163                 32      Praha
# 2          John      Moravec       725 092 179                 33      Praha
# 3      Dominika      Kopecká       722 747 626                 34      Praha
# 4        Marcel        Hájek  +421 902 928 669                 35      Praha
# 5        Milada    Hernandez       773 373 704                 38      Praha
# 6     Catherine       Bender       604 068 460                 40      Praha
# 7          Olga      Němcová  +421 914 172 243                 41      Praha
# 8       Jeffrey      Šťastný       607 628 821                 44      Praha
# 9        Kamila       Říhová  +421 948 396 069                 47      Praha
# 10      Jaromír       Miller  +421 912 615 902                 49      Praha
# ...

# %% [markdown]
# Načtení tabulky platy

# %%
platy= pandas.read_csv("platy_2021_02.csv")
platy
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %% [markdown]
# Left join obou tabulek - > obsahuje NaN, zaměstnanci, kteří v únoru již nepracují ve firmě

# %%
zamestnanci_prop= pandas.merge(zamestnanci,platy, on=["cislo_zamestnance"],how= "left")
zamestnanci_prop
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance pracoviste  \
# 0         Brian         Hall  +421 949 656 098                 30      Praha
# 1         Marta     Kolářová       730 456 163                 32      Praha
# 2          John      Moravec       725 092 179                 33      Praha
# 3      Dominika      Kopecká       722 747 626                 34      Praha
# 4        Marcel        Hájek  +421 902 928 669                 35      Praha
# 5        Milada    Hernandez       773 373 704                 38      Praha
# 6     Catherine       Bender       604 068 460                 40      Praha
# 7          Olga      Němcová  +421 914 172 243                 41      Praha
# 8       Jeffrey      Šťastný       607 628 821                 44      Praha
# 9        Kamila       Říhová  +421 948 396 069                 47      Praha
# 10      Jaromír       Miller  +421 912 615 902                 49      Praha
# ...

# %% [markdown]
# Tabulka zaměstnanců, kteří v únoru již ve frimě nepracují

# %%
zamestnanci_bezunorvyplaty= zamestnanci_prop[zamestnanci_prop["plat"].isnull()]
zamestnanci_bezunorvyplaty
# Out:
#         jmeno prijimeni   telefonni_cislo  cislo_zamestnance pracoviste  plat
# 4      Marcel     Hájek  +421 902 928 669                 35      Praha   NaN
# 12   Karolína     Short       721 589 083                 53      Praha   NaN
# 13   Michelle   Vlčková  +421 41 720 7806                 54      Praha   NaN
# 16       John    Bailey       775 021 116                 58      Praha   NaN
# 17    William   Shelton  +421 47 745 8219                 60      Praha   NaN
# 18  Miroslava    Veselá       774 029 254                 62      Praha   NaN
# 21     Nathan   Svoboda       728 710 923                 66      Praha   NaN
# 24     Robert      Říha       727 351 984                 72      Praha   NaN
# 33   Jindřich    Howell  +421 39 043 0948                 10      Plzen   NaN
# 34  Alexander  Martinez       721 195 689                 13      Plzen   NaN
# 48   Jennifer     Brown       775 545 190                 86    Liberec   NaN
# ...

# %% [markdown]
# 13 zaměstnanců bez unorové vyplaty = nepracuje ve firmě

# %%
zamestnanci_bezunorvyplaty.shape
# Out:
# (13, 6)

# %% [markdown]
# Spočti průměrný plat zaměstnanců v jednotlivých kancelářích.

# %%
zamestnanci_prop.groupby("pracoviste")["plat"].mean()
# Out:
# pracoviste
# Liberec    43775.000000
# Plzen      44792.857143
# Praha      43295.238095
# Name: plat, dtype: float64

# %% [markdown]
# Zadání 2
# Pokračuj ve své práci pro softwarovou firmu. Ze souboru vykazy.csv načti informace o výkazech na projekty pro jednoho vybraného zákazníka.
#
#     Načti data ze souboru a ulož je do tabulky.
#     Proveď agregaci a zjisti celkový počet vykázaných hodin za jednotlivé projekty.

# %%
vykazy= pandas.read_csv("vykazy.csv")
vykazy
# Out:
#           date  hours project  emloyee_id
# 0   2021-02-01    2.5     F30          13
# 1   2021-02-01    3.4     W05          70
# 2   2021-02-01    2.1     JL9          72
# 3   2021-02-01    5.2     F30           3
# 4   2021-02-01    2.4     TE1          54
# 5   2021-02-01    4.1     TE1          83
# 6   2021-02-01    5.4     W05          92
# 7   2021-02-01    2.2     YLI          34
# 8   2021-02-01    2.7     YLI          84
# 9   2021-02-01    4.4     W05          30
# 10  2021-02-02    5.6     F30          53
# 11  2021-02-02    2.6     W05          47
# 12  2021-02-02    2.4     YLI          44
# 13  2021-02-02    3.1     YLI          40
# 14  2021-02-02    5.3     YLI          10
# 15  2021-02-02    3.6     YLI          53
# 16  2021-02-02    5.6     F30          56
# 17  2021-02-03    4.0     W05          53
# 18  2021-02-03    4.6     TE1          86
# 19  2021-02-03    2.6     F30          18
# 20  2021-02-03    2.8     TE1          47
# ...

# %%
vykazy.groupby("project")["hours"].sum()
# Out:
# project
# F30    21.5
# JL9     2.1
# TE1    16.0
# W05    30.5
# YLI    31.0
# Name: hours, dtype: float64

# %% [markdown]
# Nepovinný bonus 1
#
#     Ulož do proměnné počet zaměstnanců, kteří v naší firmě již nepracují.
#     V rámci úspory se IT oddělení rozhodlo prověřit licence přidělené zaměstnancům, kteří ve firmě již nepracují. Vytvoř samostatnou tabulku, která obsahuje jména zaměstnanců, kteří ve firmě již nepracují. Tabulku ulož do souboru CSV.

# %%
jmena_byvzamestnancu= zamestnanci_bezunorvyplaty["jmeno"]
jmena_byvzamestnancu
jmena_byvzamestnancu.to_csv("jmena_byvzamestnancu,csv",index= False)

# %% [markdown]
# Nepovinný bonus 2
#
# Propoj tabulku s výkazy s tabulkou se zaměstnanci, kterou jsi vytvořil(a) v předchozím cvičení.
#
# Následně proveď statistiku vykázaných hodin za jednotlivé kanceláře, tj. spočítej celkový počet hodin vykázaný zaměstnanci jednotlivých kanceláří na projekty daného zákazníka.

# %%
vykazy=vykazy.rename(columns={"emloyee_id":"cislo_zamestnance"})
vykazy
# Out:
#           date  hours project  cislo_zamestnance
# 0   2021-02-01    2.5     F30                 13
# 1   2021-02-01    3.4     W05                 70
# 2   2021-02-01    2.1     JL9                 72
# 3   2021-02-01    5.2     F30                  3
# 4   2021-02-01    2.4     TE1                 54
# 5   2021-02-01    4.1     TE1                 83
# 6   2021-02-01    5.4     W05                 92
# 7   2021-02-01    2.2     YLI                 34
# 8   2021-02-01    2.7     YLI                 84
# 9   2021-02-01    4.4     W05                 30
# 10  2021-02-02    5.6     F30                 53
# 11  2021-02-02    2.6     W05                 47
# 12  2021-02-02    2.4     YLI                 44
# 13  2021-02-02    3.1     YLI                 40
# 14  2021-02-02    5.3     YLI                 10
# 15  2021-02-02    3.6     YLI                 53
# 16  2021-02-02    5.6     F30                 56
# 17  2021-02-03    4.0     W05                 53
# ...

# %%
zamestnanci_prop1 = pandas.merge (zamestnanci_prop,vykazy, on=["cislo_zamestnance"], how="left")

# %%
zamestnanci_prop1
# Out:
#        jmeno prijimeni   telefonni_cislo  cislo_zamestnance pracoviste  \
# 0      Brian      Hall  +421 949 656 098                 30      Praha
# 1      Marta  Kolářová       730 456 163                 32      Praha
# 2       John   Moravec       725 092 179                 33      Praha
# 3   Dominika   Kopecká       722 747 626                 34      Praha
# 4   Dominika   Kopecká       722 747 626                 34      Praha
# ..       ...       ...               ...                ...        ...
# 57      Dana     Reyes  +421 904 153 942                 90    Liberec
# 58     Vasyl    Veselý       603 759 413                 92    Liberec
# 59     Randy    Veselý       777 149 125                 95    Liberec
# 60    Audrey     Allen  +421 908 839 506                 96    Liberec
# 61      Ivan    Bartoš       603 226 051                 99    Liberec
#
#        plat        date  hours project
# 0   33500.0  2021-02-01    4.4     W05
# ...

# %%
zamestnanci_compl=zamestnanci_prop1.dropna()
zamestnanci_compl
# Out:
#         jmeno    prijimeni   telefonni_cislo  cislo_zamestnance pracoviste  \
# 0       Brian         Hall  +421 949 656 098                 30      Praha
# 3    Dominika      Kopecká       722 747 626                 34      Praha
# 4    Dominika      Kopecká       722 747 626                 34      Praha
# 7   Catherine       Bender       604 068 460                 40      Praha
# 8   Catherine       Bender       604 068 460                 40      Praha
# 10    Jeffrey      Šťastný       607 628 821                 44      Praha
# 11     Kamila       Říhová  +421 948 396 069                 47      Praha
# 12     Kamila       Říhová  +421 948 396 069                 47      Praha
# 19    Jeffrey     Pospíšil  +421 55 491 6940                 56      Praha
# 20   Ladislav       Blažek  +421 910 274 975                 57      Praha
# 28     Dillon        Black       734 300 978                 70      Praha
# ...

# %% [markdown]
# Následně proveď statistiku vykázaných hodin za jednotlivé kanceláře, tj. spočítej celkový počet hodin vykázaný zaměstnanci jednotlivých kanceláří na projekty daného zákazníka.

# %%
zamestnanci_compl.groupby(["pracoviste","project"])["hours"].sum()
# Out:
# pracoviste  project
# Liberec     TE1         6.2
#             W05         5.4
#             YLI         6.4
# Plzen       F30         7.8
# Praha       F30         5.6
#             TE1         2.8
#             W05        21.1
#             YLI        10.3
# Name: hours, dtype: float64
